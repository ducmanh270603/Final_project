# %% [markdown]
# # **Data Science Final-Project**

# %% [markdown]
# ## Content
#
# We would like to summarize the content in today's final presentation as follows:
#
# 1.   Introduction
# 2.   Analysis
# 3.   Recommendation
#
# Now, let us begin!

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Group 6
#
#
# * Dao Duc Manh as the leader
# * Nguyen Huu Hoang Phong
# * Bui Ngoc Ha
# * Nguyen Duc Phuong
# * Bui Anh Quan
# * Nguyen Manh Quang
#
#
# ### Reason for choosing the topic
#
# According to the World Health Organization (WHO) stroke is the 2nd leading cause of death globally, responsible for approximately 11% of total deaths.
#
# Our datasets is taken from Kaggle.com (https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset/data)

# %% [markdown]
# ## Analysis

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url='./healthcare-dataset-stroke-data.csv'
df=pd.read_csv(url)

# %% [markdown]
# ### Percentage of People Having Strokes

# %%
fig, ax = plt.subplots(figsize=(6,6), dpi=70) 
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['right'].set_visible(False) 
ax.spines['top'].set_visible(False)
ax.barh([1], 95, height=0.7, color='#fe346e')
ax.barh([0], 5, height=0.7, color='#512b58')
plt.text(-11, 1, 'Stroke', color='#512b58', fontweight='bold')
plt.text(57, 1, 'Healthy', color='#fe346e', fontweight='bold')
plt.text(-11, 1.8, 'Percentage of People Having Strokes', fontweight='bold')
plt.text(46, 1.7, 'Stroke', color='#512b58', fontweight='bold')
plt.text(56, 1.7, '|', color='black', fontweight='bold') 
plt.text(57, 1.7, 'Healthy', color='#fe346e', fontweight='bold')
plt.text(-11, 1.5, 'Highly unbalanced distribution,\n5 in 100 people susceptible\nto heart strokes.', font='serif', fontsize=12)
# Out:
# Text(-11, 1.5, 'Highly unbalanced distribution,\n5 in 100 people susceptible\nto heart strokes.')

# %% [markdown]
# ### Age-Stroke Distribution

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.kdeplot(data=df[df['stroke']==0], x='age', 
            shade=True, alpha=1, 
            color='blue',
            label='Healthy')
sns.kdeplot(data=df[df['stroke']==1], x='age',  
            shade=True, alpha=0.8,
            color='red',
           label='Stroke')
ax.set_xlabel('Age')
ax.set_ylabel('Density')
ax.legend()
ax.set_title('Age Distribution of Stroke and Healthy Patients')
fig.savefig('age_distribution.png')
# Out:
# C:\Users\whois\AppData\Local\Temp\ipykernel_6240\99606506.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df[df['stroke']==0], x='age',
# C:\Users\whois\AppData\Local\Temp\ipykernel_6240\99606506.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df[df['stroke']==1], x='age',

# %% [markdown]
# ### Gender and stroke

# %%
sns.countplot(x = "gender", data=df,hue="stroke");

# %% [markdown]
# ### Marital Status and Stroke

# %%
fig = px.histogram(df, x="ever_married", color="stroke",width=400, height=400)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 fig = px.histogram(df, x="ever_married", color="stroke",width=400, height=400)
#       2 fig.show()
#
# NameError: name 'px' is not defined

# %% [markdown]
# ### Hypertension, Heart_disease and Stroke

# %%
num_people = 5111  
hypertension_count = 498
heart_disease_count = 276
stroke_count = 249  

stroke_hypertension = stroke_count / hypertension_count
stroke_heart_disease = stroke_count / heart_disease_count


labels = ['Hypertension', 'Heart-disease']
sizes = [stroke_hypertension, stroke_heart_disease]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  


plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')


plt.title('Number of people with stroke by cause')
plt.show()

# %% [markdown]
# ### Residence type and stroke

# %%
urban_cases = 135
rural_cases = 114


labels = ['Urban', 'Rural']

data = [urban_cases, rural_cases]

colors = ['#ff9999', '#66b3ff']


plt.figure(figsize=(8, 8))
plt.pie(data, labels=labels, autopct='%1.1f%%', colors=colors, startangle=90)


plt.title('Chart comparing people with stroke in urban and rural areas')


plt.show()

# %% [markdown]
# ### Work Type, Smoking Status and Stroke

# %%
df[df['stroke'] == 1].groupby(['work_type', 'smoking_status']).size().unstack().plot(kind='bar', stacked=True,
            color=['#F5DEB3','#997950','#613613','#362312','yellow'])

plt.title('Compare the number of people who have had a stroke by work type and smoking status')
plt.ylabel('People who have had a stroke')
plt.xlabel('Types of jobs')
plt.show()

# %% [markdown]
# ### Glucose and stroke

# %%
avg_glucose_level = df['avg_glucose_level']
colors = ['orange']  
plt.bar(range(len(avg_glucose_level)), avg_glucose_level, color=colors)

plt.xlabel('X-label')
plt.ylabel('avg_glucose_level')
plt.title('avg_glucose_level Chart') 


plt.show()

# %% [markdown]
# ### Bmi and Stroke

# %%
plt.bar(df.index, df['bmi'], color='skyblue')
plt.xlabel('Index')
plt.ylabel('BMI')
plt.title('BMI and Stroke')

plt.show()

# %% [markdown]
# ## Recommendation
#
#
# ### - Diet
#
# An unhealthy diet can increase your chances of having a stroke because it may lead to an increase in your blood pressure and cholesterol levels.
#
#
# ### - Do Exercise
#
# Combining a healthy diet with regular exercise is the best way to maintain a healthy weight.
#
# Regular exercise can also help lower your cholesterol and keep your blood pressure healthy.
#
#
# ### - Stop Smoking
#
# Smoking significantly increases your risk of having a stroke. This is because it narrows your arteries and makes your blood more likely to clot. You can reduce your risk of having a stroke by stopping smoking.
#
# ### - Cut down on alcohol
#
# Excessive alcohol consumption can lead to high blood pressure and trigger an irregular heartbeat (atrial fibrillation), both of which can increase your risk of having a stroke.

# %% [markdown]
# # Thanks you for listening to our presentation !!
